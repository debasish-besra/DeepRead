# %%
print("all ok")
# Out:
# all ok

# %%
import logging
import os
from datetime import datetime

# %%
os.getcwd()
# Out:
# 'e:\\AI Engineer Projects\\DeepRead\\notebook'

# %%
logs_dir=os.path.join(os.getcwd(),"logs")
os.makedirs(logs_dir, exist_ok=True)
